# %% [markdown]
# # Pengubahan Tipe Data Kolom Transaksi

# %%
import pandas as pd
df = pd.read_csv('/content/transaksi.csv')
df

# %%
df['Harga Asli'] = df['Harga Asli'].replace('[Rp,]', '', regex=True).astype(float)
df['Tanggal Transaksi'] = pd.to_datetime(df['Tanggal Transaksi'], format='%Y-%m-%d')
df
# Out:
#      Unnamed: 0 Tanggal Transaksi Nama Sales  Harga Asli      Customer  \
# 0             0        2021-02-28     Octroy     41000.0           Ade
# 1             1        2021-02-09       Aini    270000.0         Qayug
# 2             2        2021-03-26     Octroy    255000.0         Ixoim
# 3             3        2021-03-20     Octroy   1025000.0         Yinoh
# 4             4        2021-04-04       Agus    130000.0  Hoosnestrond
# ..          ...               ...        ...         ...           ...
# 453         453        2021-07-04       Agus    150000.0       Shashou
# 454         454        2021-02-07       Agus    100980.0         Dejen
# 455         455        2021-04-24       Agus   6503000.0     Thauzhash
# 456         456        2021-06-08       Agus   5000000.0       Shashou
# 457         457        2021-07-07       Agus         NaN         Ixoim
#
#     Tipe Produk
# 0      Produk A
# 1      Produk A
# 2      Produk D
# 3      Produk C
# 4      Produk C
# ...

# %%
df1= df.groupby('Customer')['Harga Asli'].sum().reset_index()
df1['Harga Asli'] = df1['Harga Asli'].map('{:,.2f}'.format)
print(df1.head())
# Out:
#   Customer     Harga Asli
# 0   Abdoul   2,006,000.00
# 1      Ade  16,338,750.00
# 2  Adegoke   3,998,400.00
# 3    Axzab  11,633,980.00
# 4  Bluaxia   5,847,500.00

# %% [markdown]
# # Pengubahan Tipe Data Kolom Campaign

# %%
df3 = pd.read_excel('/content/campaign.xlsx')
print(df3)

# %%
# Membersihkan dan mengonversi kolom 'Harga Asli'
df3['Budget'] = df3['Budget'].replace('[Rp,]', '', regex=True).astype(float)
df3['Start Date'] = pd.to_datetime(df3['Start Date'], format='%Y-%m-%d')
df3['End Date	'] = pd.to_datetime(df3['End Date'], format='%Y-%m-%d')

df3
# Out:
#          Name Start Date   End Date      Budget End Date\t
# 0  Campaign 1 2021-01-01 2021-01-31  10000000.0 2021-01-31
# 1  Campaign 2 2021-02-01 2021-02-28  14000000.0 2021-02-28
# 2  Campaign 3 2021-03-01 2021-03-31  23000000.0 2021-03-31
# 3  Campaign 4 2021-04-01 2021-04-30  35000000.0 2021-04-30
# 4  Campaign 5 2021-05-01 2021-05-31  36000000.0 2021-05-31
# 5  Campaign 6 2021-06-01 2021-06-30  30000000.0 2021-06-30
# 6  Campaign 7 2021-07-01 2021-07-31  37000000.0 2021-07-31

# %% [markdown]
# # Ekspor Data

# %%
df.to_csv('transaksi_.csv')
df3.to_csv('campaign_.csv')
